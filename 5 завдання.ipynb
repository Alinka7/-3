# %%
import pandas as pd
import numpy as np
import timeit
import matplotlib.pyplot as plt
import random
# %matplotlib inline 
name='Data.csv'
frame = pd.DataFrame() 
frame = pd.read_csv(name, sep='[; ]+', engine='python')

# %%
frame = pd.read_csv(name, sep='[; ]+', engine='python')

# %%
fr100000 = frame[frame.index <= 100000]

# %%
df2 = fr100000[(fr100000.Time >= '18:00:00') & (fr100000.Global_active_power > 6) & (fr100000.Sub_metering_2 > fr100000.Sub_metering_1) & (fr100000.Sub_metering_2 > fr100000.Sub_metering_3)]
df2.reset_index(drop=True)
# Out:
#            Date      Time  Global_active_power  Global_reactive_power  \
# 0    16/12/2006  18:05:00                6.052                  0.192
# 1    16/12/2006  18:06:00                6.752                  0.186
# 2    16/12/2006  18:07:00                6.474                  0.144
# 3    16/12/2006  18:08:00                6.308                  0.116
# 4    16/12/2006  18:35:00                6.072                  0.000
# ..          ...       ...                  ...                    ...
# 174   22/2/2007  21:37:00                6.222                  0.192
# 175   22/2/2007  21:38:00                6.550                  0.172
# 176   22/2/2007  21:40:00                6.048                  0.158
# 177   22/2/2007  21:43:00                6.346                  0.114
# 178   22/2/2007  21:45:00                6.288                  0.114
#
#      Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# ...

# %%
start = timeit.default_timer()
df2_1 = df2[(df2.index < 178//2) & (df2.index % 3 == 0)]
df2_2 = df2[(df2.index >= 178//2) & (df2.index % 4 == 0)]
df3 = pd.concat([df2_1, df2_2])
a = timeit.default_timer() - start
print(a)
# Out:
# 0.003125200000795303

# %%
fr500000 = frame[frame.index <= 500000]

# %%
df = fr500000[(fr500000.Time >= '18:00:00') & (fr500000.Global_active_power > 6) & (fr500000.Sub_metering_2 > fr500000.Sub_metering_1) & (fr500000.Sub_metering_2 > fr500000.Sub_metering_3)]
df.reset_index(drop=True)
# Out:
#            Date      Time  Global_active_power  Global_reactive_power  \
# 0    16/12/2006  18:05:00                6.052                  0.192
# 1    16/12/2006  18:06:00                6.752                  0.186
# 2    16/12/2006  18:07:00                6.474                  0.144
# 3    16/12/2006  18:08:00                6.308                  0.116
# 4    16/12/2006  18:35:00                6.072                  0.000
# ..          ...       ...                  ...                    ...
# 371  12/11/2007  20:38:00                7.770                  0.368
# 372  12/11/2007  20:39:00                7.702                  0.276
# 373  12/11/2007  20:40:00                6.914                  0.250
# 374  12/11/2007  20:42:00                6.488                  0.234
# 375  17/11/2007  18:36:00                6.064                  0.446
#
#      Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# ...

# %%
start = timeit.default_timer()
df2_1 = df[(df.index < 375//2) & (df.index % 3 == 0)]
df2_2 = df[(df.index >= 375//2) & (df.index % 4 == 0)]
df3 = pd.concat([df2_1, df2_2])
b = timeit.default_timer() - start
print(b)
# Out:
# 0.005597800000032294

# %%
fr1000000 = frame[frame.index <= 1000000]

# %%
df = fr1000000[(fr1000000.Time >= '18:00:00') & (fr1000000.Global_active_power > 6) & (fr1000000.Sub_metering_2 > fr1000000.Sub_metering_1) & (fr1000000.Sub_metering_2 > fr1000000.Sub_metering_3)]
df.reset_index(drop=True)
# Out:
#            Date      Time  Global_active_power  Global_reactive_power  \
# 0    16/12/2006  18:05:00                6.052                  0.192
# 1    16/12/2006  18:06:00                6.752                  0.186
# 2    16/12/2006  18:07:00                6.474                  0.144
# 3    16/12/2006  18:08:00                6.308                  0.116
# 4    16/12/2006  18:35:00                6.072                  0.000
# ..          ...       ...                  ...                    ...
# 647   4/11/2008  21:37:00                6.882                  0.240
# 648   4/11/2008  21:38:00                6.546                  0.230
# 649   4/11/2008  21:39:00                6.316                  0.194
# 650   4/11/2008  21:40:00                6.332                  0.212
# 651   4/11/2008  21:41:00                6.316                  0.194
#
#      Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# ...

# %%
start = timeit.default_timer()
df2_1 = df[(df.index < 651//2) & (df.index % 3 == 0)]
df2_2 = df[(df.index >= 651//2) & (df.index % 4 == 0)]
df3 = pd.concat([df2_1, df2_2])
c = timeit.default_timer() - start
print(c)
# Out:
# 0.004118900000321446

# %%
fr1500000 = frame[frame.index <= 1500000]

# %%
df = fr1500000[(fr1500000.Time >= '18:00:00') & (fr1500000.Global_active_power > 6) & (fr1500000.Sub_metering_2 > fr1500000.Sub_metering_1) & (fr1500000.Sub_metering_2 > fr1500000.Sub_metering_3)]
df.reset_index(drop=True)
# Out:
#            Date      Time  Global_active_power  Global_reactive_power  \
# 0    16/12/2006  18:05:00                6.052                  0.192
# 1    16/12/2006  18:06:00                6.752                  0.186
# 2    16/12/2006  18:07:00                6.474                  0.144
# 3    16/12/2006  18:08:00                6.308                  0.116
# 4    16/12/2006  18:35:00                6.072                  0.000
# ..          ...       ...                  ...                    ...
# 881   16/6/2009  18:24:00                6.432                  0.088
# 882   16/6/2009  18:25:00                6.866                  0.088
# 883   16/6/2009  18:26:00                6.170                  0.088
# 884   13/8/2009  20:00:00                6.706                  0.296
# 885   26/8/2009  20:38:00                7.056                  0.308
#
#      Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# ...

# %%
start = timeit.default_timer()
df2_1 = df[(df.index < 885//2) & (df.index % 3 == 0)]
df2_2 = df[(df.index >= 885//2) & (df.index % 4 == 0)]
df3 = pd.concat([df2_1, df2_2])
d = timeit.default_timer() - start
print(d)
# Out:
# 0.0036873999997624196

# %%
fr2000000 = frame[frame.index <= 2049280]

# %%
df = fr2000000[(fr2000000.Time >= '18:00:00') & (fr2000000.Global_active_power > 6) & (fr2000000.Sub_metering_2 > fr2000000.Sub_metering_1) & (fr2000000.Sub_metering_2 > fr2000000.Sub_metering_3)]
df.reset_index(drop=True)
# Out:
#             Date      Time  Global_active_power  Global_reactive_power  \
# 0     16/12/2006  18:05:00                6.052                  0.192
# 1     16/12/2006  18:06:00                6.752                  0.186
# 2     16/12/2006  18:07:00                6.474                  0.144
# 3     16/12/2006  18:08:00                6.308                  0.116
# 4     16/12/2006  18:35:00                6.072                  0.000
# ...          ...       ...                  ...                    ...
# 1056  20/11/2010  18:44:00                6.374                  0.392
# 1057  20/11/2010  18:45:00                6.564                  0.430
# 1058  20/11/2010  18:46:00                6.438                  0.308
# 1059  20/11/2010  18:49:00                6.210                  0.174
# 1060  20/11/2010  18:52:00                6.364                  0.126
#
#       Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# ...

# %%
start = timeit.default_timer()
df2_1 = df[(df.index < 1060//2) & (df.index % 3 == 0)]
df2_2 = df[(df.index >= 1060//2) & (df.index % 4 == 0)]
df3 = pd.concat([df2_1, df2_2])
e = timeit.default_timer() - start
print(e)
# Out:
# 0.004649100001188344

# %%
m_els = np.genfromtxt('Data.csv', dtype={'names':('Date', 'Time', 'Global_active_power', 'Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3'), 'formats':('U8', 'U8', 'f8', 'f8', 'f8', 'f8', 'f8', 'f8', 'f8')}, delimiter=';')

# %%
m_els = np.delete(m_els, (0), axis=0)

# %%
mels100 = m_els[0:100000]

# %%
m = mels100[(mels100['Time'] >= '18:00:00')& (mels100['Global_active_power'] >= 6)& (mels100['Sub_metering_2'] > mels100['Sub_metering_1']) & (mels100['Sub_metering_2']> mels100['Sub_metering_3'])]

# %%
start = timeit.default_timer()
fr6 = m[0:179//2:3]
fr7 = m[179//2:179:4]
fr8 = np.append(fr6,fr7)
a1 = timeit.default_timer() - start
print(a1)
# Out:
# 0.0003243000010115793

# %%
mels100 = m_els[0:500000]

# %%
m = mels100[(mels100['Time'] >= '18:00:00')& (mels100['Global_active_power'] >= 6)& (mels100['Sub_metering_2'] > mels100['Sub_metering_1']) & (mels100['Sub_metering_2']> mels100['Sub_metering_3'])]

# %%
start = timeit.default_timer()
fr6 = m[0:376//2:3]
fr7 = m[376//2:376:4]
fr8 = np.append(fr6,fr7)
b1 = timeit.default_timer() - start
print(b1)
# Out:
# 0.0003620999996201135

# %%
mels100 = m_els[0:1000000]

# %%
m = mels100[(mels100['Time'] >= '18:00:00')& (mels100['Global_active_power'] >= 6)& (mels100['Sub_metering_2'] > mels100['Sub_metering_1']) & (mels100['Sub_metering_2']> mels100['Sub_metering_3'])]

# %%
start = timeit.default_timer()
fr6 = m[0:652//2:3]
fr7 = m[652//2:652:4]
fr8 = np.append(fr6,fr7)
c1 = timeit.default_timer() - start
print(c1)
# Out:
# 0.0004341000003478257

# %%
mels100 = m_els[0:1500000]

# %%
m = mels100[(mels100['Time'] >= '18:00:00')& (mels100['Global_active_power'] >= 6)& (mels100['Sub_metering_2'] > mels100['Sub_metering_1']) & (mels100['Sub_metering_2']> mels100['Sub_metering_3'])]

# %%
start = timeit.default_timer()
fr6 = m[0:886//2:3]
fr7 = m[886//2:886:4]
fr8 = np.append(fr6,fr7)
d1 = timeit.default_timer() - start
print(d1)
# Out:
# 0.0008326999995915685

# %%
mels100 = m_els[0:2049280]

# %%
m = mels100[(mels100['Time'] >= '18:00:00')& (mels100['Global_active_power'] >= 6)& (mels100['Sub_metering_2'] > mels100['Sub_metering_1']) & (mels100['Sub_metering_2']> mels100['Sub_metering_3'])]

# %%
start = timeit.default_timer()
fr6 = m[0:1063//2:3]
fr7 = m[1063//2:1063:4]
fr8 = np.append(fr6,fr7)
e1 = timeit.default_timer() - start
print(e1)
# Out:
# 0.0008651999996800441

# %%
x = [100000,500000, 1000000,1500000,2049280]
y = [a, b, c, d, e]

x1 = [100000,500000, 1000000,1500000,2049280]
y1 = [a1, b1, c1, d1, e1]

plt.plot(x1,y1,color="blue")
plt.plot(x,y,color="red")
